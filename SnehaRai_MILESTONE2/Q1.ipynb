# %%
import sqlite3

# %%
import pandas as pd

# %%
df = pd.read_csv(r'dataset_1.csv')
df
# Out:
#      Age  EstimatedSalary  Purchased
# 0     19            19000          0
# 1     35            20000          0
# 2     26            43000          0
# 3     27            57000          0
# 4     19            76000          0
# ..   ...              ...        ...
# 395   46            41000          1
# 396   51            23000          1
# 397   50            20000          1
# 398   36            33000          0
# 399   49            36000          1
#
# [400 rows x 3 columns]

# %%
from sklearn import preprocessing
scaler = preprocessing.MinMaxScaler()
d = preprocessing.normalize(df,axis=0)
scaled_df = pd.DataFrame(d, columns=['Age','EstimatedSalary','Purchased'])
scaled_df
# Out:
#           Age  EstimatedSalary  Purchased
# 0    0.024307         0.012240   0.000000
# 1    0.044776         0.012885   0.000000
# 2    0.033262         0.027702   0.000000
# 3    0.034541         0.036721   0.000000
# 4    0.024307         0.048961   0.000000
# 5    0.034541         0.037365   0.000000
# 6    0.034541         0.054115   0.000000
# 7    0.040938         0.096634   0.083624
# 8    0.031983         0.021259   0.000000
# 9    0.044776         0.041875   0.000000
# 10   0.033262         0.051538   0.000000
# 11   0.033262         0.033500   0.000000
# 12   0.025586         0.055403   0.000000
# 13   0.040938         0.011596   0.000000
# 14   0.023028         0.052826   0.000000
# 15   0.037100         0.051538   0.000000
# 16   0.060128         0.016106   0.083624
# 17   0.057569         0.016750   0.083624
# 18   0.058848         0.018038   0.083624
# 19   0.061407         0.018683   0.083624
# 20   0.057569         0.014173   0.083624
# ...
